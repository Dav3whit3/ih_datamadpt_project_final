# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Index

# %% [markdown]
# 1 - API data\
# 2 - Data preprocessing\
# 3 -

# %%
## APi Key to arg parse

# %%
summoner = 'Saikki kusuo'
key = 'RGAPI-9724b32a-f354-408c-8cde-8fdcc35e01fa'

# %% [markdown]
# Summoner v4, /lol/summoner/v4/summoners/by-name/{summonerName}\
# Get summoner info by name using API key and summoner name

# %%
# Summoner v4, /lol/summoner/v4/summoners/by-name/{summonerName}
# Get summoner info by name using API key and summoner name

def get_accountid(summoner_name, apikey):
    # This function takes the summoner name and the API Key
    # and retrieves its account id
    url = f'https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/{summoner_name}'
    html = requests.get(url,
                       params={'api_key': key})
    json = html.json()
    accid = json['accountId']
    
    return accid

# %%
accountId = get_accountid(summoner, key)
accountId
# Out:
# 'djQlAoXhpBz5y5YjoYJkpS-kVvZQx4Caj8DElKzSEPmJo8c'

# %%
def get_matchlist(accountid, api):
    
    url = f'https://euw1.api.riotgames.com/lol/match/v4/matchlists/by-account/{accountId}'
    html = requests.get(url,
                       params={'api_key': key})
    json = html.json()
    
    return json

# %%
mygames = get_matchlist(accountId, key)

# %%
mygames.keys()
# Out:
# dict_keys(['matches', 'startIndex', 'endIndex', 'totalGames'])

# %%
mygames = pd.DataFrame(mygames['matches'])
mygames.head()
# Out:
#   platformId      gameId  champion  queue  season      timestamp       role  \
# 0       EUW1  4852948640       360    420      13  1601905357003  DUO_CARRY
# 1       EUW1  4852952829        81    420      13  1601902637078       SOLO
# 2       EUW1  4852774276       145    420      13  1601891814800  DUO_CARRY
# 3       EUW1  4852688998        81    420      13  1601887255733  DUO_CARRY
# 4       EUW1  4851471050       104    420      13  1601820301766       NONE
#
#      lane
# 0  BOTTOM
# 1  BOTTOM
# 2  BOTTOM
# 3  BOTTOM
# 4  JUNGLE

# %%
# Match v4, /lol/match/v4/matches/{matchId}
# Get match info using gameid
def get_match_info(matchid):
    
    url = f'https://euw1.api.riotgames.com/lol/match/v4/matches/{matchid}'
    html = requests.get(url,
                    params={'api_key': key})
    json = html.json()
    
    return json

# %%
match = get_match_info(4834424471)

# %%
match.keys()
# Out:
# dict_keys(['gameId', 'platformId', 'gameCreation', 'gameDuration', 'queueId', 'mapId', 'seasonId', 'gameVersion', 'gameMode', 'gameType', 'teams', 'participants', 'participantIdentities'])

# %%
match['participants']
# Out:
# [{'participantId': 1,
#   'teamId': 100,
#   'championId': 150,
#   'spell1Id': 4,
#   'spell2Id': 14,
#   'stats': {'participantId': 1,
#    'win': False,
#    'item0': 1055,
#    'item1': 3071,
#    'item2': 3022,
#    'item3': 3075,
#    'item4': 3111,
#    'item5': 3091,
#    'item6': 3340,
#    'kills': 10,
#    'deaths': 5,
#    'assists': 9,
#    'largestKillingSpree': 5,
#    'largestMultiKill': 2,
#    'killingSprees': 2,
#    'longestTimeSpentLiving': 1235,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 140619,
#    'magicDamageDealt': 19495,
#    'physicalDamageDealt': 110398,
#    'trueDamageDealt': 10725,
#    'largestCriticalStrike': 24,
#    'totalDamageDealtToChampions': 28837,
#    'magicDamageDealtToChampions': 6340,
#    'physicalDamageDealtToChampions': 20971,
#    'trueDamageDealtToChampions': 1525,
#    'totalHeal': 6836,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 47581,
#    'damageDealtToObjectives': 10346,
#    'damageDealtToTurrets': 5114,
#    'visionScore': 11,
#    'timeCCingOthers': 74,
#    'totalDamageTaken': 38845,
#    'magicalDamageTaken': 9825,
#    'physicalDamageTaken': 27188,
#    'trueDamageTaken': 1832,
#    'goldEarned': 14815,
#    'goldSpent': 14100,
#    'turretKills': 2,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 187,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 756,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 5,
#    'wardsKilled': 2,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8021,
#    'perk0Var1': 2571,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 9111,
#    'perk1Var1': 2015,
#    'perk1Var2': 380,
#    'perk1Var3': 0,
#    'perk2': 9104,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8014,
#    'perk3Var1': 563,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8446,
#    'perk4Var1': 2322,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8473,
#    'perk5Var1': 648,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8400,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 1,
#    'creepsPerMinDeltas': {'10-20': 6.8999999999999995,
#     '0-10': 7.4,
#     '20-30': 3.1},
#    'xpPerMinDeltas': {'10-20': 489.59999999999997,
#     '0-10': 447.5,
#     '20-30': 396.3},
#    'goldPerMinDeltas': {'10-20': 529.8, '0-10': 289.3, '20-30': 487.4},
#    'csDiffPerMinDeltas': {'10-20': 3.3,
#     '0-10': 1.4000000000000004,
#     '20-30': -0.3999999999999999},
#    'xpDiffPerMinDeltas': {'10-20': 163.79999999999998,
#     '0-10': 7.399999999999977,
#     '20-30': -135.69999999999996},
#    'damageTakenPerMinDeltas': {'10-20': 789.6,
#     '0-10': 246.89999999999998,
#     '20-30': 1926.8},
#    'damageTakenDiffPerMinDeltas': {'10-20': -184.49999999999997,
#     '0-10': -36.500000000000014,
#     '20-30': 951.2},
#    'role': 'SOLO',
#    'lane': 'TOP'}},
#  {'participantId': 2,
#   'teamId': 100,
#   'championId': 875,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 2,
#    'win': False,
#    'item0': 3748,
#    'item1': 1401,
#    'item2': 3111,
#    'item3': 3076,
#    'item4': 3742,
#    'item5': 1028,
#    'item6': 3340,
#    'kills': 6,
#    'deaths': 7,
#    'assists': 16,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 667,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 134442,
#    'magicDamageDealt': 32983,
#    'physicalDamageDealt': 84618,
#    'trueDamageDealt': 16840,
#    'largestCriticalStrike': 8,
#    'totalDamageDealtToChampions': 26403,
#    'magicDamageDealtToChampions': 3882,
#    'physicalDamageDealtToChampions': 14622,
#    'trueDamageDealtToChampions': 7897,
#    'totalHeal': 11062,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 53560,
#    'damageDealtToObjectives': 6705,
#    'damageDealtToTurrets': 1304,
#    'visionScore': 31,
#    'timeCCingOthers': 50,
#    'totalDamageTaken': 48464,
#    'magicalDamageTaken': 13462,
#    'physicalDamageTaken': 34448,
#    'trueDamageTaken': 554,
#    'goldEarned': 11635,
#    'goldSpent': 11685,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 41,
#    'neutralMinionsKilled': 100,
#    'neutralMinionsKilledTeamJungle': 67,
#    'neutralMinionsKilledEnemyJungle': 12,
#    'totalTimeCrowdControlDealt': 372,
#    'champLevel': 15,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 12,
#    'wardsKilled': 4,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8230,
#    'perk0Var1': 28,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8275,
#    'perk1Var1': 27,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8234,
#    'perk2Var1': 10915,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8232,
#    'perk3Var1': 5,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8306,
#    'perk4Var1': 3,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8410,
#    'perk5Var1': 131,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8200,
#    'perkSubStyle': 8300,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 2,
#    'creepsPerMinDeltas': {'10-20': 0.9, '0-10': 0.1, '20-30': 2.3},
#    'xpPerMinDeltas': {'10-20': 345.29999999999995,
#     '0-10': 279.1,
#     '20-30': 608.8},
#    'goldPerMinDeltas': {'10-20': 362.70000000000005,
#     '0-10': 265.1,
#     '20-30': 365.9},
#    'csDiffPerMinDeltas': {'10-20': -0.4, '0-10': -0.1, '20-30': 1.5},
#    'xpDiffPerMinDeltas': {'10-20': 6.299999999999983,
#     '0-10': -35.10000000000002,
#     '20-30': 129.2},
#    'damageTakenPerMinDeltas': {'10-20': 1226.8000000000002,
#     '0-10': 562.4,
#     '20-30': 2042.3},
#    'damageTakenDiffPerMinDeltas': {'10-20': 41.200000000000045,
#     '0-10': -145.9,
#     '20-30': -179.89999999999998},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'participantId': 3,
#   'teamId': 100,
#   'championId': 117,
#   'spell1Id': 14,
#   'spell2Id': 4,
#   'stats': {'participantId': 3,
#    'win': False,
#    'item0': 3853,
#    'item1': 3504,
#    'item2': 3117,
#    'item3': 3174,
#    'item4': 3114,
#    'item5': 3801,
#    'item6': 3364,
#    'kills': 0,
#    'deaths': 13,
#    'assists': 20,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 0,
#    'killingSprees': 0,
#    'longestTimeSpentLiving': 278,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 28096,
#    'magicDamageDealt': 21131,
#    'physicalDamageDealt': 5378,
#    'trueDamageDealt': 1586,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 14814,
#    'magicDamageDealtToChampions': 11228,
#    'physicalDamageDealtToChampions': 2000,
#    'trueDamageDealtToChampions': 1586,
#    'totalHeal': 2429,
#    'totalUnitsHealed': 3,
#    'damageSelfMitigated': 14275,
#    'damageDealtToObjectives': 757,
#    'damageDealtToTurrets': 581,
#    'visionScore': 47,
#    'timeCCingOthers': 38,
#    'totalDamageTaken': 22283,
#    'magicalDamageTaken': 4881,
#    'physicalDamageTaken': 16770,
#    'trueDamageTaken': 632,
#    'goldEarned': 8378,
#    'goldSpent': 7500,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 21,
#    'neutralMinionsKilled': 4,
#    'neutralMinionsKilledTeamJungle': 4,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 263,
#    'champLevel': 13,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 24,
#    'wardsKilled': 4,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8214,
#    'perk0Var1': 1001,
#    'perk0Var2': 2072,
#    'perk0Var3': 0,
#    'perk1': 8226,
#    'perk1Var1': 250,
#    'perk1Var2': 546,
#    'perk1Var3': 0,
#    'perk2': 8210,
#    'perk2Var1': 0,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8237,
#    'perk3Var1': 495,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8347,
#    'perk4Var1': 0,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8345,
#    'perk5Var1': 3,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8200,
#    'perkSubStyle': 8300,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 3,
#    'creepsPerMinDeltas': {'10-20': 0.5,
#     '0-10': 1,
#     '20-30': 0.6000000000000001},
#    'xpPerMinDeltas': {'10-20': 314.1,
#     '0-10': 283.29999999999995,
#     '20-30': 414.1},
#    'goldPerMinDeltas': {'10-20': 284.2, '0-10': 170.1, '20-30': 263.1},
#    'csDiffPerMinDeltas': {'10-20': -1.45,
#     '0-10': -1.15,
#     '20-30': -0.9499999999999998},
#    'xpDiffPerMinDeltas': {'10-20': -65,
#     '0-10': -8.65000000000002,
#     '20-30': -81.49999999999997},
#    'damageTakenPerMinDeltas': {'10-20': 586.5,
#     '0-10': 246.79999999999998,
#     '20-30': 766.4000000000001},
#    'damageTakenDiffPerMinDeltas': {'10-20': -180.34999999999997,
#     '0-10': -25.900000000000034,
#     '20-30': -383.25},
#    'role': 'DUO_SUPPORT',
#    'lane': 'BOTTOM'}},
#  {'participantId': 4,
#   'teamId': 100,
#   'championId': 67,
#   'spell1Id': 4,
#   'spell2Id': 7,
#   'stats': {'participantId': 4,
#    'win': False,
#    'item0': 1055,
#    'item1': 3153,
#    'item2': 2421,
#    'item3': 3124,
#    'item4': 3046,
#    'item5': 3006,
#    'item6': 3340,
#    'kills': 11,
#    'deaths': 13,
#    'assists': 8,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 1,
#    'killingSprees': 3,
#    'longestTimeSpentLiving': 368,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 110860,
#    'magicDamageDealt': 2761,
#    'physicalDamageDealt': 73682,
#    'trueDamageDealt': 34416,
#    'largestCriticalStrike': 391,
#    'totalDamageDealtToChampions': 29842,
#    'magicDamageDealtToChampions': 1724,
#    'physicalDamageDealtToChampions': 20030,
#    'trueDamageDealtToChampions': 8086,
#    'totalHeal': 4665,
#    'totalUnitsHealed': 4,
#    'damageSelfMitigated': 14536,
#    'damageDealtToObjectives': 3242,
#    'damageDealtToTurrets': 1866,
#    'visionScore': 18,
#    'timeCCingOthers': 22,
#    'totalDamageTaken': 32808,
#    'magicalDamageTaken': 12036,
#    'physicalDamageTaken': 19873,
#    'trueDamageTaken': 898,
#    'goldEarned': 12508,
#    'goldSpent': 11500,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 107,
#    'neutralMinionsKilled': 4,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 45,
#    'champLevel': 14,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 11,
#    'wardsKilled': 2,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8005,
#    'perk0Var1': 1774,
#    'perk0Var2': 1118,
#    'perk0Var3': 655,
#    'perk1': 9111,
#    'perk1Var1': 1067,
#    'perk1Var2': 380,
#    'perk1Var3': 0,
#    'perk2': 9104,
#    'perk2Var1': 19,
#    'perk2Var2': 10,
#    'perk2Var3': 0,
#    'perk3': 8014,
#    'perk3Var1': 511,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8275,
#    'perk4Var1': 12,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8236,
#    'perk5Var1': 28,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8200,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 4,
#    'creepsPerMinDeltas': {'10-20': 3.5, '0-10': 3.6, '20-30': 2.6},
#    'xpPerMinDeltas': {'10-20': 466.7,
#     '0-10': 270.5,
#     '20-30': 424.29999999999995},
#    'goldPerMinDeltas': {'10-20': 372.2, '0-10': 246.8, '20-30': 411.4},
#    'csDiffPerMinDeltas': {'10-20': -1.45,
#     '0-10': -1.15,
#     '20-30': -0.9499999999999998},
#    'xpDiffPerMinDeltas': {'10-20': -65,
#     '0-10': -8.65000000000002,
#     '20-30': -81.49999999999997},
#    'damageTakenPerMinDeltas': {'10-20': 745.9000000000001,
#     '0-10': 384.1,
#     '20-30': 1334.2},
#    'damageTakenDiffPerMinDeltas': {'10-20': -180.34999999999997,
#     '0-10': -25.900000000000034,
#     '20-30': -383.25},
#    'role': 'DUO_CARRY',
#    'lane': 'BOTTOM'}},
#  {'participantId': 5,
#   'teamId': 100,
#   'championId': 45,
#   'spell1Id': 21,
#   'spell2Id': 4,
#   'stats': {'participantId': 5,
#    'win': False,
#    'item0': 3020,
#    'item1': 3030,
#    'item2': 3157,
#    'item3': 1058,
#    'item4': 3285,
#    'item5': 1058,
#    'item6': 3340,
#    'kills': 9,
#    'deaths': 8,
#    'assists': 10,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 2,
#    'killingSprees': 2,
#    'longestTimeSpentLiving': 523,
#    'doubleKills': 3,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 185545,
#    'magicDamageDealt': 170390,
#    'physicalDamageDealt': 11644,
#    'trueDamageDealt': 3510,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 32000,
#    'magicDamageDealtToChampions': 29601,
#    'physicalDamageDealtToChampions': 1442,
#    'trueDamageDealtToChampions': 957,
#    'totalHeal': 3238,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 16320,
#    'damageDealtToObjectives': 3454,
#    'damageDealtToTurrets': 2491,
#    'visionScore': 40,
#    'timeCCingOthers': 45,
#    'totalDamageTaken': 25040,
#    'magicalDamageTaken': 11255,
#    'physicalDamageTaken': 13495,
#    'trueDamageTaken': 290,
#    'goldEarned': 13696,
#    'goldSpent': 13025,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 166,
#    'neutralMinionsKilled': 40,
#    'neutralMinionsKilledTeamJungle': 32,
#    'neutralMinionsKilledEnemyJungle': 4,
#    'totalTimeCrowdControlDealt': 230,
#    'champLevel': 17,
#    'visionWardsBoughtInGame': 3,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 18,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8351,
#    'perk0Var1': 26,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8304,
#    'perk1Var1': 11,
#    'perk1Var2': 1,
#    'perk1Var3': 5,
#    'perk2': 8345,
#    'perk2Var1': 3,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8347,
#    'perk3Var1': 0,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8139,
#    'perk4Var1': 1529,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8134,
#    'perk5Var1': 35,
#    'perk5Var2': 5,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8300,
#    'perkSubStyle': 8100,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 5,
#    'creepsPerMinDeltas': {'10-20': 4.8,
#     '0-10': 5.199999999999999,
#     '20-30': 4.199999999999999},
#    'xpPerMinDeltas': {'10-20': 464.6, '0-10': 399.5, '20-30': 578.8},
#    'goldPerMinDeltas': {'10-20': 329.5, '0-10': 221.5, '20-30': 584.4},
#    'csDiffPerMinDeltas': {'10-20': -1.3000000000000003,
#     '0-10': -1.5000000000000004,
#     '20-30': -1.4000000000000004},
#    'xpDiffPerMinDeltas': {'10-20': 80.79999999999998,
#     '0-10': -65.30000000000001,
#     '20-30': -7.599999999999966},
#    'damageTakenPerMinDeltas': {'10-20': 760.5, '0-10': 289, '20-30': 954.4},
#    'damageTakenDiffPerMinDeltas': {'10-20': -350.40000000000003,
#     '0-10': 67.7,
#     '20-30': -252.40000000000003},
#    'role': 'SOLO',
#    'lane': 'MIDDLE'}},
#  {'participantId': 6,
#   'teamId': 200,
#   'championId': 44,
#   'spell1Id': 4,
#   'spell2Id': 14,
#   'stats': {'participantId': 6,
#    'win': True,
#    'item0': 3110,
#    'item1': 3190,
#    'item2': 3860,
#    'item3': 3117,
#    'item4': 3050,
#    'item5': 3109,
#    'item6': 3364,
#    'kills': 4,
#    'deaths': 9,
#    'assists': 30,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 571,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 44619,
#    'magicDamageDealt': 26210,
#    'physicalDamageDealt': 11549,
#    'trueDamageDealt': 6860,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 15209,
#    'magicDamageDealtToChampions': 10115,
#    'physicalDamageDealtToChampions': 3799,
#    'trueDamageDealtToChampions': 1294,
#    'totalHeal': 19967,
#    'totalUnitsHealed': 5,
#    'damageSelfMitigated': 52651,
#    'damageDealtToObjectives': 3659,
#    'damageDealtToTurrets': 1024,
#    'visionScore': 54,
#    'timeCCingOthers': 47,
#    'totalDamageTaken': 33484,
#    'magicalDamageTaken': 12270,
#    'physicalDamageTaken': 15655,
#    'trueDamageTaken': 5558,
#    'goldEarned': 12277,
#    'goldSpent': 11325,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 40,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 538,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 5,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 21,
#    'wardsKilled': 5,
#    'firstBloodKill': True,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': True,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8465,
#    'perk0Var1': 4669,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8463,
#    'perk1Var1': 954,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8473,
#    'perk2Var1': 914,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8453,
#    'perk3Var1': 1981,
#    'perk3Var2': 1079,
#    'perk3Var3': 0,
#    'perk4': 8009,
#    'perk4Var1': 6338,
#    'perk4Var2': 500,
#    'perk4Var3': 0,
#    'perk5': 9105,
#    'perk5Var1': 13,
#    'perk5Var2': 50,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8400,
#    'perkSubStyle': 8000,
#    'statPerk0': 5005,
#    'statPerk1': 5002,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 6,
#    'creepsPerMinDeltas': {'10-20': 1.7000000000000002,
#     '0-10': 1.4,
#     '20-30': 0.7999999999999999},
#    'xpPerMinDeltas': {'10-20': 398.8, '0-10': 292.3, '20-30': 451.4},
#    'goldPerMinDeltas': {'10-20': 393.70000000000005,
#     '0-10': 271.6,
#     '20-30': 306.5},
#    'csDiffPerMinDeltas': {'10-20': 1.45,
#     '0-10': 1.15,
#     '20-30': 0.9499999999999998},
#    'xpDiffPerMinDeltas': {'10-20': 65,
#     '0-10': 8.65000000000002,
#     '20-30': 81.49999999999997},
#    'damageTakenPerMinDeltas': {'10-20': 834.6, '0-10': 339.6, '20-30': 1617.2},
#    'damageTakenDiffPerMinDeltas': {'10-20': 180.34999999999997,
#     '0-10': 25.900000000000034,
#     '20-30': 383.25},
#    'role': 'DUO_SUPPORT',
#    'lane': 'BOTTOM'}},
#  {'participantId': 7,
#   'teamId': 200,
#   'championId': 106,
#   'spell1Id': 4,
#   'spell2Id': 12,
#   'stats': {'participantId': 7,
#    'win': True,
#    'item0': 1054,
#    'item1': 3068,
#    'item2': 3111,
#    'item3': 3076,
#    'item4': 3078,
#    'item5': 3082,
#    'item6': 3340,
#    'kills': 4,
#    'deaths': 6,
#    'assists': 7,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'killingSprees': 2,
#    'longestTimeSpentLiving': 787,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 121919,
#    'magicDamageDealt': 67254,
#    'physicalDamageDealt': 49444,
#    'trueDamageDealt': 5220,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 14650,
#    'magicDamageDealtToChampions': 6143,
#    'physicalDamageDealtToChampions': 8507,
#    'trueDamageDealtToChampions': 0,
#    'totalHeal': 2808,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 29147,
#    'damageDealtToObjectives': 7434,
#    'damageDealtToTurrets': 5827,
#    'visionScore': 27,
#    'timeCCingOthers': 23,
#    'totalDamageTaken': 25784,
#    'magicalDamageTaken': 8575,
#    'physicalDamageTaken': 14107,
#    'trueDamageTaken': 3101,
#    'goldEarned': 11356,
#    'goldSpent': 10208,
#    'turretKills': 3,
#    'inhibitorKills': 1,
#    'totalMinionsKilled': 162,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 299,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 12,
#    'wardsKilled': 2,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8005,
#    'perk0Var1': 1161,
#    'perk0Var2': 881,
#    'perk0Var3': 279,
#    'perk1': 9111,
#    'perk1Var1': 813,
#    'perk1Var2': 220,
#    'perk1Var3': 0,
#    'perk2': 9104,
#    'perk2Var1': 25,
#    'perk2Var2': 30,
#    'perk2Var3': 0,
#    'perk3': 8299,
#    'perk3Var1': 309,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8275,
#    'perk4Var1': 8,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 2,
#    'perk5Var2': 10,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8200,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 7,
#    'creepsPerMinDeltas': {'10-20': 3.6, '0-10': 6, '20-30': 3.5},
#    'xpPerMinDeltas': {'10-20': 325.79999999999995,
#     '0-10': 440.1,
#     '20-30': 532},
#    'goldPerMinDeltas': {'10-20': 277, '0-10': 221.6, '20-30': 372.2},
#    'csDiffPerMinDeltas': {'10-20': -3.3,
#     '0-10': -1.4000000000000004,
#     '20-30': 0.3999999999999999},
#    'xpDiffPerMinDeltas': {'10-20': -163.79999999999998,
#     '0-10': -7.399999999999977,
#     '20-30': 135.69999999999996},
#    'damageTakenPerMinDeltas': {'10-20': 974.1,
#     '0-10': 283.4,
#     '20-30': 975.5999999999999},
#    'damageTakenDiffPerMinDeltas': {'10-20': 184.49999999999997,
#     '0-10': 36.500000000000014,
#     '20-30': -951.2},
#    'role': 'SOLO',
#    'lane': 'TOP'}},
#  {'participantId': 8,
#   'teamId': 200,
#   'championId': 202,
#   'spell1Id': 4,
#   'spell2Id': 7,
#   'stats': {'participantId': 8,
#    'win': True,
#    'item0': 3026,
#    'item1': 3095,
#    'item2': 3009,
#    'item3': 3031,
#    'item4': 3094,
#    'item5': 3046,
#    'item6': 3340,
#    'kills': 23,
#    'deaths': 6,
#    'assists': 14,
#    'largestKillingSpree': 6,
#    'largestMultiKill': 3,
#    'killingSprees': 5,
#    'longestTimeSpentLiving': 687,
#    'doubleKills': 3,
#    'tripleKills': 1,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 223499,
#    'magicDamageDealt': 10037,
#    'physicalDamageDealt': 205072,
#    'trueDamageDealt': 8390,
#    'largestCriticalStrike': 2613,
#    'totalDamageDealtToChampions': 61181,
#    'magicDamageDealtToChampions': 6488,
#    'physicalDamageDealtToChampions': 52762,
#    'trueDamageDealtToChampions': 1930,
#    'totalHeal': 9216,
#    'totalUnitsHealed': 4,
#    'damageSelfMitigated': 20765,
#    'damageDealtToObjectives': 21521,
#    'damageDealtToTurrets': 5242,
#    'visionScore': 21,
#    'timeCCingOthers': 60,
#    'totalDamageTaken': 30339,
#    'magicalDamageTaken': 8451,
#    'physicalDamageTaken': 18408,
#    'trueDamageTaken': 3479,
#    'goldEarned': 19672,
#    'goldSpent': 16500,
#    'turretKills': 3,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 165,
#    'neutralMinionsKilled': 40,
#    'neutralMinionsKilledTeamJungle': 20,
#    'neutralMinionsKilledEnemyJungle': 4,
#    'totalTimeCrowdControlDealt': 239,
#    'champLevel': 17,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 10,
#    'wardsKilled': 2,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': True,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8021,
#    'perk0Var1': 3266,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8009,
#    'perk1Var1': 3631,
#    'perk1Var2': 500,
#    'perk1Var3': 0,
#    'perk2': 9103,
#    'perk2Var1': 18,
#    'perk2Var2': 50,
#    'perk2Var3': 0,
#    'perk3': 8014,
#    'perk3Var1': 1285,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8275,
#    'perk4Var1': 10,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8236,
#    'perk5Var1': 28,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 8,
#    'creepsPerMinDeltas': {'10-20': 5.2, '0-10': 5.5, '20-30': 4.3},
#    'xpPerMinDeltas': {'10-20': 512, '0-10': 278.8, '20-30': 550},
#    'goldPerMinDeltas': {'10-20': 580, '0-10': 287.2, '20-30': 692},
#    'csDiffPerMinDeltas': {'10-20': 1.45,
#     '0-10': 1.15,
#     '20-30': 0.9499999999999998},
#    'xpDiffPerMinDeltas': {'10-20': 65,
#     '0-10': 8.65000000000002,
#     '20-30': 81.49999999999997},
#    'damageTakenPerMinDeltas': {'10-20': 858.5, '0-10': 343.1, '20-30': 1249.9},
#    'damageTakenDiffPerMinDeltas': {'10-20': 180.34999999999997,
#     '0-10': 25.900000000000034,
#     '20-30': 383.25},
#    'role': 'DUO_CARRY',
#    'lane': 'BOTTOM'}},
#  {'participantId': 9,
#   'teamId': 200,
#   'championId': 84,
#   'spell1Id': 12,
#   'spell2Id': 4,
#   'stats': {'participantId': 9,
#    'win': True,
#    'item0': 1056,
#    'item1': 3157,
#    'item2': 3146,
#    'item3': 3151,
#    'item4': 3020,
#    'item5': 1026,
#    'item6': 3340,
#    'kills': 10,
#    'deaths': 6,
#    'assists': 4,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'killingSprees': 3,
#    'longestTimeSpentLiving': 734,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 188153,
#    'magicDamageDealt': 150371,
#    'physicalDamageDealt': 31532,
#    'trueDamageDealt': 6249,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 30955,
#    'magicDamageDealtToChampions': 26767,
#    'physicalDamageDealtToChampions': 4043,
#    'trueDamageDealtToChampions': 144,
#    'totalHeal': 11823,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 23648,
#    'damageDealtToObjectives': 6825,
#    'damageDealtToTurrets': 5784,
#    'visionScore': 30,
#    'timeCCingOthers': 6,
#    'totalDamageTaken': 33505,
#    'magicalDamageTaken': 8215,
#    'physicalDamageTaken': 20905,
#    'trueDamageTaken': 4384,
#    'goldEarned': 15634,
#    'goldSpent': 12225,
#    'turretKills': 3,
#    'inhibitorKills': 1,
#    'totalMinionsKilled': 218,
#    'neutralMinionsKilled': 15,
#    'neutralMinionsKilledTeamJungle': 4,
#    'neutralMinionsKilledEnemyJungle': 5,
#    'totalTimeCrowdControlDealt': 84,
#    'champLevel': 17,
#    'visionWardsBoughtInGame': 3,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 13,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8010,
#    'perk0Var1': 693,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8009,
#    'perk1Var1': 573,
#    'perk1Var2': 50,
#    'perk1Var3': 0,
#    'perk2': 9104,
#    'perk2Var1': 20,
#    'perk2Var2': 40,
#    'perk2Var3': 0,
#    'perk3': 8014,
#    'perk3Var1': 624,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8138,
#    'perk4Var1': 30,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8106,
#    'perk5Var1': 4,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8100,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5003},
#   'timeline': {'participantId': 9,
#    'creepsPerMinDeltas': {'10-20': 6.1, '0-10': 6.7, '20-30': 5.6},
#    'xpPerMinDeltas': {'10-20': 383.8, '0-10': 464.8, '20-30': 586.4},
#    'goldPerMinDeltas': {'10-20': 353.7,
#     '0-10': 306.29999999999995,
#     '20-30': 535.2},
#    'csDiffPerMinDeltas': {'10-20': 1.3000000000000003,
#     '0-10': 1.5000000000000004,
#     '20-30': 1.4000000000000004},
#    'xpDiffPerMinDeltas': {'10-20': -80.79999999999998,
#     '0-10': 65.30000000000001,
#     '20-30': 7.599999999999966},
#    'damageTakenPerMinDeltas': {'10-20': 1110.9,
#     '0-10': 221.3,
#     '20-30': 1206.8},
#    'damageTakenDiffPerMinDeltas': {'10-20': 350.40000000000003,
#     '0-10': -67.7,
#     '20-30': 252.40000000000003},
#    'role': 'SOLO',
#    'lane': 'MIDDLE'}},
#  {'participantId': 10,
#   'teamId': 200,
#   'championId': 141,
#   'spell1Id': 11,
#   'spell2Id': 4,
#   'stats': {'participantId': 10,
#    'win': True,
#    'item0': 1400,
#    'item1': 3812,
#    'item2': 3047,
#    'item3': 3071,
#    'item4': 3076,
#    'item5': 0,
#    'item6': 3364,
#    'kills': 5,
#    'deaths': 9,
#    'assists': 6,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 790,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 186112,
#    'magicDamageDealt': 7150,
#    'physicalDamageDealt': 166329,
#    'trueDamageDealt': 12633,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 22191,
#    'magicDamageDealtToChampions': 0,
#    'physicalDamageDealtToChampions': 21353,
#    'trueDamageDealtToChampions': 838,
#    'totalHeal': 23853,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 37185,
#    'damageDealtToObjectives': 38029,
#    'damageDealtToTurrets': 1344,
#    'visionScore': 20,
#    'timeCCingOthers': 31,
#    'totalDamageTaken': 49905,
#    'magicalDamageTaken': 18132,
#    'physicalDamageTaken': 27874,
#    'trueDamageTaken': 3898,
#    'goldEarned': 11928,
#    'goldSpent': 11625,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 33,
#    'neutralMinionsKilled': 133,
#    'neutralMinionsKilledTeamJungle': 91,
#    'neutralMinionsKilledEnemyJungle': 7,
#    'totalTimeCrowdControlDealt': 299,
#    'champLevel': 15,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 3,
#    'wardsKilled': 3,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8010,
#    'perk0Var1': 827,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 9111,
#    'perk1Var1': 607,
#    'perk1Var2': 220,
#    'perk1Var3': 0,
#    'perk2': 9103,
#    'perk2Var1': 25,
#    'perk2Var2': 50,
#    'perk2Var3': 0,
#    'perk3': 8299,
#    'perk3Var1': 696,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8143,
#    'perk4Var1': 532,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8135,
#    'perk5Var1': 4273,
#    'perk5Var2': 5,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8100,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 10,
#    'creepsPerMinDeltas': {'10-20': 1.3,
#     '0-10': 0.2,
#     '20-30': 0.7999999999999999},
#    'xpPerMinDeltas': {'10-20': 339,
#     '0-10': 314.20000000000005,
#     '20-30': 479.6},
#    'goldPerMinDeltas': {'10-20': 335, '0-10': 227.5, '20-30': 398.8},
#    'csDiffPerMinDeltas': {'10-20': 0.4, '0-10': 0.1, '20-30': -1.5},
#    'xpDiffPerMinDeltas': {'10-20': -6.299999999999983,
#     '0-10': 35.10000000000002,
#     '20-30': -129.2},
#    'damageTakenPerMinDeltas': {'10-20': 1185.6,
#     '0-10': 708.3,
#     '20-30': 2222.2},
#    'damageTakenDiffPerMinDeltas': {'10-20': -41.200000000000045,
#     '0-10': 145.9,
#     '20-30': 179.89999999999998},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}}]

# %%
match['participants'][2]
# Out:
# {'participantId': 3,
#  'teamId': 100,
#  'championId': 117,
#  'spell1Id': 14,
#  'spell2Id': 4,
#  'stats': {'participantId': 3,
#   'win': False,
#   'item0': 3853,
#   'item1': 3504,
#   'item2': 3117,
#   'item3': 3174,
#   'item4': 3114,
#   'item5': 3801,
#   'item6': 3364,
#   'kills': 0,
#   'deaths': 13,
#   'assists': 20,
#   'largestKillingSpree': 0,
#   'largestMultiKill': 0,
#   'killingSprees': 0,
#   'longestTimeSpentLiving': 278,
#   'doubleKills': 0,
#   'tripleKills': 0,
#   'quadraKills': 0,
#   'pentaKills': 0,
#   'unrealKills': 0,
#   'totalDamageDealt': 28096,
#   'magicDamageDealt': 21131,
#   'physicalDamageDealt': 5378,
#   'trueDamageDealt': 1586,
#   'largestCriticalStrike': 0,
#   'totalDamageDealtToChampions': 14814,
#   'magicDamageDealtToChampions': 11228,
#   'physicalDamageDealtToChampions': 2000,
#   'trueDamageDealtToChampions': 1586,
#   'totalHeal': 2429,
#   'totalUnitsHealed': 3,
#   'damageSelfMitigated': 14275,
#   'damageDealtToObjectives': 757,
#   'damageDealtToTurrets': 581,
#   'visionScore': 47,
#   'timeCCingOthers': 38,
#   'totalDamageTaken': 22283,
#   'magicalDamageTaken': 4881,
#   'physicalDamageTaken': 16770,
#   'trueDamageTaken': 632,
#   'goldEarned': 8378,
#   'goldSpent': 7500,
#   'turretKills': 0,
#   'inhibitorKills': 0,
#   'totalMinionsKilled': 21,
#   'neutralMinionsKilled': 4,
#   'neutralMinionsKilledTeamJungle': 4,
#   'neutralMinionsKilledEnemyJungle': 0,
#   'totalTimeCrowdControlDealt': 263,
#   'champLevel': 13,
#   'visionWardsBoughtInGame': 2,
#   'sightWardsBoughtInGame': 0,
#   'wardsPlaced': 24,
#   'wardsKilled': 4,
#   'firstBloodKill': False,
#   'firstBloodAssist': False,
#   'firstTowerKill': False,
#   'firstTowerAssist': False,
#   'firstInhibitorKill': False,
#   'firstInhibitorAssist': False,
#   'combatPlayerScore': 0,
#   'objectivePlayerScore': 0,
#   'totalPlayerScore': 0,
#   'totalScoreRank': 0,
#   'playerScore0': 0,
#   'playerScore1': 0,
#   'playerScore2': 0,
#   'playerScore3': 0,
#   'playerScore4': 0,
#   'playerScore5': 0,
#   'playerScore6': 0,
#   'playerScore7': 0,
#   'playerScore8': 0,
#   'playerScore9': 0,
#   'perk0': 8214,
#   'perk0Var1': 1001,
#   'perk0Var2': 2072,
#   'perk0Var3': 0,
#   'perk1': 8226,
#   'perk1Var1': 250,
#   'perk1Var2': 546,
#   'perk1Var3': 0,
#   'perk2': 8210,
#   'perk2Var1': 0,
#   'perk2Var2': 0,
#   'perk2Var3': 0,
#   'perk3': 8237,
#   'perk3Var1': 495,
#   'perk3Var2': 0,
#   'perk3Var3': 0,
#   'perk4': 8347,
#   'perk4Var1': 0,
#   'perk4Var2': 0,
#   'perk4Var3': 0,
#   'perk5': 8345,
#   'perk5Var1': 3,
#   'perk5Var2': 0,
#   'perk5Var3': 0,
#   'perkPrimaryStyle': 8200,
#   'perkSubStyle': 8300,
#   'statPerk0': 5008,
#   'statPerk1': 5008,
#   'statPerk2': 5002},
#  'timeline': {'participantId': 3,
#   'creepsPerMinDeltas': {'10-20': 0.5, '0-10': 1, '20-30': 0.6000000000000001},
#   'xpPerMinDeltas': {'10-20': 314.1,
#    '0-10': 283.29999999999995,
#    '20-30': 414.1},
#   'goldPerMinDeltas': {'10-20': 284.2, '0-10': 170.1, '20-30': 263.1},
#   'csDiffPerMinDeltas': {'10-20': -1.45,
#    '0-10': -1.15,
#    '20-30': -0.9499999999999998},
#   'xpDiffPerMinDeltas': {'10-20': -65,
#    '0-10': -8.65000000000002,
#    '20-30': -81.49999999999997},
#   'damageTakenPerMinDeltas': {'10-20': 586.5,
#    '0-10': 246.79999999999998,
#    '20-30': 766.4000000000001},
#   'damageTakenDiffPerMinDeltas': {'10-20': -180.34999999999997,
#    '0-10': -25.900000000000034,
#    '20-30': -383.25},
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM'}}

# %%
players = pd.DataFrame()

for participant in range(10):
    df = pd.DataFrame.from_dict(match['participants'][participant]['stats'], orient='index').T
    df.insert(loc=0, column='championId', value= match['participants'][participant]['championId'])
    df.insert(loc=1, column='teamId', value=match['participants'][participant]['teamId'])
    players = players.append(df)
    
players.insert(loc=0, column='gameid', value=[match['gameId'] for value in range(len(players))])

# %%
players
# Out:
#        gameid  championId  teamId participantId    win item0 item1 item2  \
# 0  4834424471         150     100             1  False  1055  3071  3022
# 0  4834424471         875     100             2  False  3748  1401  3111
# 0  4834424471         117     100             3  False  3853  3504  3117
# 0  4834424471          67     100             4  False  1055  3153  2421
# 0  4834424471          45     100             5  False  3020  3030  3157
# 0  4834424471          44     200             6   True  3110  3190  3860
# 0  4834424471         106     200             7   True  1054  3068  3111
# 0  4834424471         202     200             8   True  3026  3095  3009
# 0  4834424471          84     200             9   True  1056  3157  3146
# 0  4834424471         141     200            10   True  1400  3812  3047
#
#   item3 item4  ... perk4Var3 perk5 perk5Var1 perk5Var2 perk5Var3  \
# 0  3075  3111  ...         0  8473       648         0         0
# 0  3076  3742  ...         0  8410       131         0         0
# 0  3174  3114  ...         0  8345         3         0         0
# 0  3124  3046  ...         0  8236        28         0         0
# 0  1058  3285  ...         0  8134        35         5         0
# 0  3117  3050  ...         0  9105        13        50         0
# 0  3076  3078  ...         0  8232         2        10         0
# 0  3031  3094  ...         0  8236        28         0         0
# 0  3151  3020  ...         0  8106         4         0         0
# 0  3071  3076  ...         0  8135      4273         5         0
#
#   perkPrimaryStyle perkSubStyle statPerk0 statPerk1 statPerk2
# 0             8000         8400      5005      5008      5002
# 0             8200         8300      5005      5008      5002
# 0             8200         8300      5008      5008      5002
# 0             8000         8200      5005      5008      5002
# 0             8300         8100      5008      5008      5002
# 0             8400         8000      5005      5002      5002
# 0             8000         8200      5005      5008      5002
# 0             8000         8200      5008      5008      5002
# 0             8000         8100      5008      5008      5003
# 0             8000         8100      5005      5008      5002
#
# [10 rows x 107 columns]

# %%
players.columns.to_list()
# Out:
# ['gameid',
#  'championId',
#  'teamId',
#  'participantId',
#  'win',
#  'item0',
#  'item1',
#  'item2',
#  'item3',
#  'item4',
#  'item5',
#  'item6',
#  'kills',
#  'deaths',
#  'assists',
#  'largestKillingSpree',
#  'largestMultiKill',
#  'killingSprees',
#  'longestTimeSpentLiving',
#  'doubleKills',
#  'tripleKills',
#  'quadraKills',
#  'pentaKills',
#  'unrealKills',
#  'totalDamageDealt',
#  'magicDamageDealt',
#  'physicalDamageDealt',
#  'trueDamageDealt',
#  'largestCriticalStrike',
#  'totalDamageDealtToChampions',
#  'magicDamageDealtToChampions',
#  'physicalDamageDealtToChampions',
#  'trueDamageDealtToChampions',
#  'totalHeal',
#  'totalUnitsHealed',
#  'damageSelfMitigated',
#  'damageDealtToObjectives',
#  'damageDealtToTurrets',
#  'visionScore',
#  'timeCCingOthers',
#  'totalDamageTaken',
#  'magicalDamageTaken',
#  'physicalDamageTaken',
#  'trueDamageTaken',
#  'goldEarned',
#  'goldSpent',
#  'turretKills',
#  'inhibitorKills',
#  'totalMinionsKilled',
#  'neutralMinionsKilled',
#  'neutralMinionsKilledTeamJungle',
#  'neutralMinionsKilledEnemyJungle',
#  'totalTimeCrowdControlDealt',
#  'champLevel',
#  'visionWardsBoughtInGame',
#  'sightWardsBoughtInGame',
#  'wardsPlaced',
#  'wardsKilled',
#  'firstBloodKill',
#  'firstBloodAssist',
#  'firstTowerKill',
#  'firstTowerAssist',
#  'firstInhibitorKill',
#  'firstInhibitorAssist',
#  'combatPlayerScore',
#  'objectivePlayerScore',
#  'totalPlayerScore',
#  'totalScoreRank',
#  'playerScore0',
#  'playerScore1',
#  'playerScore2',
#  'playerScore3',
#  'playerScore4',
#  'playerScore5',
#  'playerScore6',
#  'playerScore7',
#  'playerScore8',
#  'playerScore9',
#  'perk0',
#  'perk0Var1',
#  'perk0Var2',
#  'perk0Var3',
#  'perk1',
#  'perk1Var1',
#  'perk1Var2',
#  'perk1Var3',
#  'perk2',
#  'perk2Var1',
#  'perk2Var2',
#  'perk2Var3',
#  'perk3',
#  'perk3Var1',
#  'perk3Var2',
#  'perk3Var3',
#  'perk4',
#  'perk4Var1',
#  'perk4Var2',
#  'perk4Var3',
#  'perk5',
#  'perk5Var1',
#  'perk5Var2',
#  'perk5Var3',
#  'perkPrimaryStyle',
#  'perkSubStyle',
#  'statPerk0',
#  'statPerk1',
#  'statPerk2']

# %%
player_info = pd.DataFrame()

for elem in range(len(match['participantIdentities'])):
    df = pd.DataFrame.from_dict(match['participantIdentities'][elem]['player'], orient='index').T
    df.insert(loc=0, column='participantId', value= match['participantIdentities'][elem]['participantId'])
    player_info = player_info.append(df)

# %%
merge = pd.merge(players, player_info, on='participantId')

# %%
merge
# Out:
#        gameid  championId  teamId participantId    win item0 item1 item2  \
# 0  4834424471         150     100             1  False  1055  3071  3022
# 1  4834424471         875     100             2  False  3748  1401  3111
# 2  4834424471         117     100             3  False  3853  3504  3117
# 3  4834424471          67     100             4  False  1055  3153  2421
# 4  4834424471          45     100             5  False  3020  3030  3157
# 5  4834424471          44     200             6   True  3110  3190  3860
# 6  4834424471         106     200             7   True  1054  3068  3111
# 7  4834424471         202     200             8   True  3026  3095  3009
# 8  4834424471          84     200             9   True  1056  3157  3146
# 9  4834424471         141     200            10   True  1400  3812  3047
#
#   item3 item4  ... statPerk1 statPerk2 platformId  \
# 0  3075  3111  ...      5008      5002       EUW1
# 1  3076  3742  ...      5008      5002       EUW1
# 2  3174  3114  ...      5008      5002       EUW1
# 3  3124  3046  ...      5008      5002       EUW1
# 4  1058  3285  ...      5008      5002       EUW1
# 5  3117  3050  ...      5002      5002       EUW1
# 6  3076  3078  ...      5008      5002       EUW1
# 7  3031  3094  ...      5008      5002       EUW1
# 8  3151  3020  ...      5008      5003       EUW1
# 9  3071  3076  ...      5008      5002       EUW1
#
#                                          accountId   summonerName  \
# 0   cxpp71Wk6A8e5g-Oe_w2SLKCbFbJe-cqXt9TRkiyoNS7gg      gavilan93
# 1  yo29J_PdeL-809dylLKGpMb-o4YyAGhgbE8mhJdzwvyqv30         xSlein
# 2  HpPKtIGVN34YdUekXjP5GQ0l1fSsTfk7w8FSALSFW1z4zTk     SeifReturn
# 3   zmMT0SToH4oLvXPSuFwvizfD-7WC9lwD86AsAdv8dmG0cw        Akimari
# 4   Ok-hbQOVEt9x2SVYnKZSbycWeM5fZc-7JAyKLu7gRG33Ww       personel
# 5  Jyt5n2Rwtsm8LHYD2_Ae5JTvshfiTwwBRXYi3mrdH_bo9Us         Skíron
# 6   mxBWMdjd0VhMSJ0lBBhaW6rplFs4waLEjHHNa-JECsdmAw  Sir Cuncision
# 7   D1X8dw_Mcg11-4Uo53wEyStLvCQGl0xbd3JA3h6tE2ep9A        6ixnine
# 8  djQlAoXhpBz5y5YjoYJkpS-kVvZQx4Caj8DElKzSEPmJo8c   Saikki Kusuo
# 9  Pw9vzObhdOJVNkgu5F3d_P74bT4wflfFOa2kJU3cS-NajF0      Hacker404
#
#                                          summonerId currentPlatformId  \
# 0   5naoSf9Tuxgd8LpC7FgvvhOHdEjJi5S6mTjsmAgPerDVN_M              EUW1
# 1   0j4-M3pyKdStielmJHmJN9_PlSC7itPMhqaQZeCTATHFkcM              EUW1
# 2  IK9QQ6IuibJjFJjfwdqLgq7a7MQs-IqXPWUEGyIHpKPZyXjo              EUW1
# 3   xlZAfVeGPL-lNOw3LppkckT9SAnH8gqio9w36QK5oBISW5k              EUW1
# 4   -a6BUFuLyO3vRV6pkUKkIwJ3MlGuZWvAWqlilReKlDx1ncs              EUW1
# 5  eVRPsYgXgBFQDod5uCwftXj9HwUnIey4AT6dyRExrfSTt7OP              EUW1
# 6   BO30gVocWNUa8Ho4LcRBRCa3SuNyEhgaaOW-g3P9q0iAnaA              EUW1
# 7   XfV6AAkCgoUZ9Og0qH-g7IAW0mr4NsydtBmbGGYSs_bWpx0              EUW1
# 8   iqJz7QEm4AJIHuEKecIyvBZ65qaANfGcYM9iYL-S_FT2ddQ              EUW1
# 9   H2cx9tNUCLYghIaQtX4LZsmaGq9OFL2S3ogBWuugx11JGd0              EUW1
#
#                                   currentAccountId  \
# 0   cxpp71Wk6A8e5g-Oe_w2SLKCbFbJe-cqXt9TRkiyoNS7gg
# 1  yo29J_PdeL-809dylLKGpMb-o4YyAGhgbE8mhJdzwvyqv30
# 2  HpPKtIGVN34YdUekXjP5GQ0l1fSsTfk7w8FSALSFW1z4zTk
# 3   zmMT0SToH4oLvXPSuFwvizfD-7WC9lwD86AsAdv8dmG0cw
# 4   Ok-hbQOVEt9x2SVYnKZSbycWeM5fZc-7JAyKLu7gRG33Ww
# 5  Jyt5n2Rwtsm8LHYD2_Ae5JTvshfiTwwBRXYi3mrdH_bo9Us
# 6   mxBWMdjd0VhMSJ0lBBhaW6rplFs4waLEjHHNa-JECsdmAw
# 7   D1X8dw_Mcg11-4Uo53wEyStLvCQGl0xbd3JA3h6tE2ep9A
# 8  djQlAoXhpBz5y5YjoYJkpS-kVvZQx4Caj8DElKzSEPmJo8c
# 9  Pw9vzObhdOJVNkgu5F3d_P74bT4wflfFOa2kJU3cS-NajF0
#
#                            matchHistoryUri profileIcon
# 0   /v1/stats/player_history/EUW1/27312474        3233
# 1  /v1/stats/player_history/EUW1/212478720        3807
# 2  /v1/stats/player_history/EUW1/239688242        4656
# 3   /v1/stats/player_history/EUW1/37244478        4656
# 4   /v1/stats/player_history/EUW1/33347436         582
# 5  /v1/stats/player_history/EUW1/219285021        2076
# 6   /v1/stats/player_history/EUW1/41198240        3151
# 7   /v1/stats/player_history/EUW1/24947195        4057
# 8  /v1/stats/player_history/EUW1/229546365        4249
# 9  /v1/stats/player_history/EUW1/202459306        4512
#
# [10 rows x 115 columns]

# %%
merge.columns.to_list()
# Out:
# ['gameid',
#  'championId',
#  'teamId',
#  'participantId',
#  'win',
#  'item0',
#  'item1',
#  'item2',
#  'item3',
#  'item4',
#  'item5',
#  'item6',
#  'kills',
#  'deaths',
#  'assists',
#  'largestKillingSpree',
#  'largestMultiKill',
#  'killingSprees',
#  'longestTimeSpentLiving',
#  'doubleKills',
#  'tripleKills',
#  'quadraKills',
#  'pentaKills',
#  'unrealKills',
#  'totalDamageDealt',
#  'magicDamageDealt',
#  'physicalDamageDealt',
#  'trueDamageDealt',
#  'largestCriticalStrike',
#  'totalDamageDealtToChampions',
#  'magicDamageDealtToChampions',
#  'physicalDamageDealtToChampions',
#  'trueDamageDealtToChampions',
#  'totalHeal',
#  'totalUnitsHealed',
#  'damageSelfMitigated',
#  'damageDealtToObjectives',
#  'damageDealtToTurrets',
#  'visionScore',
#  'timeCCingOthers',
#  'totalDamageTaken',
#  'magicalDamageTaken',
#  'physicalDamageTaken',
#  'trueDamageTaken',
#  'goldEarned',
#  'goldSpent',
#  'turretKills',
#  'inhibitorKills',
#  'totalMinionsKilled',
#  'neutralMinionsKilled',
#  'neutralMinionsKilledTeamJungle',
#  'neutralMinionsKilledEnemyJungle',
#  'totalTimeCrowdControlDealt',
#  'champLevel',
#  'visionWardsBoughtInGame',
#  'sightWardsBoughtInGame',
#  'wardsPlaced',
#  'wardsKilled',
#  'firstBloodKill',
#  'firstBloodAssist',
#  'firstTowerKill',
#  'firstTowerAssist',
#  'firstInhibitorKill',
#  'firstInhibitorAssist',
#  'combatPlayerScore',
#  'objectivePlayerScore',
#  'totalPlayerScore',
#  'totalScoreRank',
#  'playerScore0',
#  'playerScore1',
#  'playerScore2',
#  'playerScore3',
#  'playerScore4',
#  'playerScore5',
#  'playerScore6',
#  'playerScore7',
#  'playerScore8',
#  'playerScore9',
#  'perk0',
#  'perk0Var1',
#  'perk0Var2',
#  'perk0Var3',
#  'perk1',
#  'perk1Var1',
#  'perk1Var2',
#  'perk1Var3',
#  'perk2',
#  'perk2Var1',
#  'perk2Var2',
#  'perk2Var3',
#  'perk3',
#  'perk3Var1',
#  'perk3Var2',
#  'perk3Var3',
#  'perk4',
#  'perk4Var1',
#  'perk4Var2',
#  'perk4Var3',
#  'perk5',
#  'perk5Var1',
#  'perk5Var2',
#  'perk5Var3',
#  'perkPrimaryStyle',
#  'perkSubStyle',
#  'statPerk0',
#  'statPerk1',
#  'statPerk2',
#  'platformId',
#  'accountId',
#  'summonerName',
#  'summonerId',
#  'currentPlatformId',
#  'currentAccountId',
#  'matchHistoryUri',
#  'profileIcon']

# %% [markdown]
# ## Game timeline

# %%
def get_match_timeline(matchid):

    url= f'https://euw1.api.riotgames.com/lol/match/v4/timelines/by-match/{matchid}'
    html = requests.get(url,
                       params={'api_key': key})
    json = html.json()
    
    return json

# %%
tl = get_match_timeline(4834424471)

tl.keys()
# Out:
# dict_keys(['frames', 'frameInterval'])

# %%
tl['frames'][0].keys()
# Out:
# dict_keys(['participantFrames', 'events', 'timestamp'])

# %%
len(tl['frames'])
# Out:
# 36

# %%
tl['frames'][35]['timestamp']
# Out:
# 2100600

# %%
it = tl['frames'][16]['participantFrames']

a = pd.DataFrame(columns=['participantId', 'x', 'y' 'currentGold', 'totalGold', 'level', 'xp',
                          'minionsKilled', 'jungleMinionsKilled', 'dominionScore', 'teamScore'])
it
# Out:
# {'1': {'participantId': 1,
#   'position': {'x': 6651, 'y': 8250},
#   'currentGold': 268,
#   'totalGold': 5768,
#   'level': 11,
#   'xp': 7416,
#   'minionsKilled': 126,
#   'jungleMinionsKilled': 0,
#   'dominionScore': 0,
#   'teamScore': 0},
#  '2': {'participantId': 2,
#   'position': {'x': 6911, 'y': 7908},
#   'currentGold': 276,
#   'totalGold': 5151,
#   'level': 8,
#   'xp': 4619,
#   'minionsKilled': 5,
#   'jungleMinionsKilled': 68,
#   'dominionScore': 0,
#   'teamScore': 0},
#  '3': {'participantId': 5,
#   'position': {'x': 4740, 'y': 8217},
#   'currentGold': 710,
#   'totalGold': 4585,
#   'level': 10,
#   'xp': 6511,
#   'minionsKilled': 83,
#   'jungleMinionsKilled': 8,
#   'dominionScore': 0,
#   'teamScore': 0},
#  '4': {'participantId': 4,
#   'position': {'x': 13574, 'y': 3655},
#   'currentGold': 826,
#   'totalGold': 4476,
#   'level': 8,
#   'xp': 4273,
#   'minionsKilled': 53,
#   'jungleMinionsKilled': 0,
#   'dominionScore': 0,
#   'teamScore': 0},
#  '5': {'participantId': 3,
#   'position': {'x': 4759, 'y': 9514},
#   'currentGold': 452,
#   'totalGold': 3627,
#   'level': 7,
#   'xp': 3878,
#   'minionsKilled': 13,
#   'jungleMinionsKilled': 4,
#   'dominionScore': 0,
#   'teamScore': 0},
#  '6': {'participantId': 7,
#   'position': {'x': 5548, 'y': 8613},
#   'currentGold': 1493,
#   'totalGold': 4718,
#   'level': 10,
#   'xp': 6901,
#   'minionsKilled': 84,
#   'jungleMinionsKilled': 0,
#   'dominionScore': 0,
#   'teamScore': 0},
#  '7': {'participantId': 10,
#   'position': {'x': 7326, 'y': 7678},
#   'currentGold': 1372,
#   'totalGold': 4897,
#   'level': 9,
#   'xp': 5313,
#   'minionsKilled': 11,
#   'jungleMinionsKilled': 85,
#   'dominionScore': 0,
#   'teamScore': 0},
#  '8': {'participantId': 9,
#   'position': {'x': 12934, 'y': 3361},
#   'currentGold': 191,
#   'totalGold': 6001,
#   'level': 10,
#   'xp': 7188,
#   'minionsKilled': 106,
#   'jungleMinionsKilled': 0,
#   'dominionScore': 0,
#   'teamScore': 0},
#  '9': {'participantId': 8,
#   'position': {'x': 7393, 'y': 8001},
#   'currentGold': 403,
#   'totalGold': 7178,
#   'level': 9,
#   'xp': 5920,
#   'minionsKilled': 92,
#   'jungleMinionsKilled': 4,
#   'dominionScore': 0,
#   'teamScore': 0},
#  '10': {'participantId': 6,
#   'position': {'x': 5542, 'y': 8514},
#   'currentGold': 561,
#   'totalGold': 5961,
#   'level': 9,
#   'xp': 5370,
#   'minionsKilled': 21,
#   'jungleMinionsKilled': 0,
#   'dominionScore': 0,
#   'teamScore': 0}}

# %%
for elem in it:
    dic = {}
    for sub_elem in it[elem]:         
        if type(it[elem][sub_elem]) == dict:
            dic.update(it[elem][sub_elem])
        else:
            dic[sub_elem] = it[elem][sub_elem]
    a = a.append(pd.DataFrame(dic, index=[0]))
# Out:
#   participantId      x ycurrentGold totalGold level    xp minionsKilled  \
# 0             1   6651          NaN      5768    11  7416           126
# 0             2   6911          NaN      5151     8  4619             5
# 0             5   4740          NaN      4585    10  6511            83
# 0             4  13574          NaN      4476     8  4273            53
# 0             3   4759          NaN      3627     7  3878            13
# 0             7   5548          NaN      4718    10  6901            84
# 0            10   7326          NaN      4897     9  5313            11
# 0             9  12934          NaN      6001    10  7188           106
# 0             8   7393          NaN      7178     9  5920            92
# 0             6   5542          NaN      5961     9  5370            21
#
#   jungleMinionsKilled dominionScore teamScore       y  currentGold
# 0                   0             0         0  8250.0        268.0
# 0                  68             0         0  7908.0        276.0
# 0                   8             0         0  8217.0        710.0
# 0                   0             0         0  3655.0        826.0
# 0                   4             0         0  9514.0        452.0
# 0                   0             0         0  8613.0       1493.0
# 0                  85             0         0  7678.0       1372.0
# 0                   0             0         0  3361.0        191.0
# 0                   4             0         0  8001.0        403.0
# 0                   0             0         0  8514.0        561.0

# %%
# Out:
# array([0], dtype=object)

# %%
def participant_frames(json):
    participant_frames = pd.DataFrame(columns=['participantId', 'x', 'y' 'currentGold', 'totalGold', 'level', 'xp',
                          'minionsKilled', 'jungleMinionsKilled', 'dominionScore', 'teamScore', 'timestamp'])
    
    length = list(range(len(json)))
    for frame in lenght:
        iterable = json['frames'][frame]['participantFrames']
        for elem in iterable:
            dic = {}
            for sub_elem in iterable[elem]:         
                if type(iterable[elem][sub_elem]) == dict:
                    dic.update(iterable[elem][sub_elem])
                else:
                    dic[sub_elem] = iterable[elem][sub_elem]
            df = pd.DataFrame(dic, index=[0])
            df.insert(loc=0, column='timestamp', value=json['frames'][frame]['timestamp'])
            participant_frames = participant_frames.append(df, ignore_index=True)
    return participant_frames

# %%
participant_frames(tl)
# Out:
#     participantId    x ycurrentGold totalGold level     xp minionsKilled  \
# 0               1  560          NaN       500     1      0             0
# 1               2  560          NaN       500     1      0             0
# 2               5  351          NaN       500     1      0             0
# 3               4  221          NaN       500     1      0             0
# 4               3  311          NaN       500     1      0             0
# ..            ...  ...          ...       ...   ...    ...           ...
# 355             7  NaN          NaN     11356    16  16005           162
# 356            10  NaN          NaN     11928    15  13986            33
# 357             9  NaN          NaN     15634    17  18178           218
# 358             8  NaN          NaN     19672    17  17591           165
# 359             6  NaN          NaN     12277    16  15228            40
#
#     jungleMinionsKilled dominionScore teamScore timestamp      y  currentGold
# 0                     0             0         0         0  581.0        500.0
# 1                     0             0         0         0  361.0        500.0
# 2                     0             0         0         0  293.0        500.0
# 3                     0             0         0         0  471.0        500.0
# 4                     0             0         0         0  649.0        500.0
# ..                  ...           ...       ...       ...    ...          ...
# 355                   0           NaN       NaN   2100600    NaN       1148.0
# 356                 133           NaN       NaN   2100600    NaN        303.0
# 357                  15           NaN       NaN   2100600    NaN       3409.0
# 358                  40           NaN       NaN   2100600    NaN       3172.0
# 359                   0           NaN       NaN   2100600    NaN        952.0
#
# [360 rows x 13 columns]

# %%
tl['frames'][35]
# Out:
# {'participantFrames': {'1': {'participantId': 1,
#    'currentGold': 715,
#    'totalGold': 14815,
#    'level': 16,
#    'xp': 14964,
#    'minionsKilled': 187,
#    'jungleMinionsKilled': 0},
#   '2': {'participantId': 2,
#    'currentGold': -50,
#    'totalGold': 11635,
#    'level': 15,
#    'xp': 14511,
#    'minionsKilled': 41,
#    'jungleMinionsKilled': 100},
#   '3': {'participantId': 5,
#    'currentGold': 671,
#    'totalGold': 13696,
#    'level': 17,
#    'xp': 16989,
#    'minionsKilled': 166,
#    'jungleMinionsKilled': 40},
#   '4': {'participantId': 4,
#    'currentGold': 1008,
#    'totalGold': 12508,
#    'level': 14,
#    'xp': 12828,
#    'minionsKilled': 107,
#    'jungleMinionsKilled': 4},
#   '5': {'participantId': 3,
#    'currentGold': 878,
#    'totalGold': 8378,
#    'level': 13,
#    'xp': 10586,
#    'minionsKilled': 21,
#    'jungleMinionsKilled': 4},
#   '6': {'participantId': 7,
#    'currentGold': 1148,
#    'totalGold': 11356,
#    'level': 16,
#    'xp': 16005,
#    'minionsKilled': 162,
#    'jungleMinionsKilled': 0},
#   '7': {'participantId': 10,
#    'currentGold': 303,
#    'totalGold': 11928,
#    'level': 15,
#    'xp': 13986,
#    'minionsKilled': 33,
#    'jungleMinionsKilled': 133},
#   '8': {'participantId': 9,
#    'currentGold': 3409,
#    'totalGold': 15634,
#    'level': 17,
#    'xp': 18178,
#    'minionsKilled': 218,
#    'jungleMinionsKilled': 15},
#   '9': {'participantId': 8,
#    'currentGold': 3172,
#    'totalGold': 19672,
#    'level': 17,
#    'xp': 17591,
#    'minionsKilled': 165,
#    'jungleMinionsKilled': 40},
#   '10': {'participantId': 6,
#    'currentGold': 952,
#    'totalGold': 12277,
#    'level': 16,
#    'xp': 15228,
#    'minionsKilled': 40,
#    'jungleMinionsKilled': 0}},
#  'events': [{'type': 'ITEM_PURCHASED',
#    'timestamp': 2048231,
#    'participantId': 2,
#    'itemId': 3076},
#   {'type': 'ITEM_DESTROYED',
#    'timestamp': 2048231,
#    'participantId': 2,
#    'itemId': 1029},
#   {'type': 'BUILDING_KILL',
#    'timestamp': 2048992,
#    'position': {'x': 1171, 'y': 3571},
#    'killerId': 0,
#    'assistingParticipantIds': [],
#    'teamId': 100,
#    'buildingType': 'INHIBITOR_BUILDING',
#    'laneType': 'TOP_LANE',
#    'towerType': 'UNDEFINED_TURRET'},
#   {'type': 'CHAMPION_KILL',
#    'timestamp': 2049454,
#    'position': {'x': 1974, 'y': 1007},
#    'killerId': 9,
#    'victimId': 5,
#    'assistingParticipantIds': [8, 6]},
#   {'type': 'SKILL_LEVEL_UP',
#    'timestamp': 2051603,
#    'participantId': 6,
#    'skillSlot': 4,
#    'levelUpType': 'NORMAL'},
#   {'type': 'WARD_PLACED',
#    'timestamp': 2053783,
#    'wardType': 'UNDEFINED',
#    'creatorId': 8},
#   {'type': 'WARD_PLACED',
#    'timestamp': 2055600,
#    'wardType': 'YELLOW_TRINKET',
#    'creatorId': 9},
#   {'type': 'CHAMPION_KILL',
#    'timestamp': 2057946,
#    'position': {'x': 1679, 'y': 797},
#    'killerId': 8,
#    'victimId': 3,
#    'assistingParticipantIds': [6]},
#   {'type': 'ITEM_DESTROYED',
#    'timestamp': 2063362,
#    'participantId': 4,
#    'itemId': 2420},
#   {'type': 'BUILDING_KILL',
#    'timestamp': 2064985,
#    'position': {'x': 3452, 'y': 1236},
#    'killerId': 9,
#    'assistingParticipantIds': [6],
#    'teamId': 100,
#    'buildingType': 'INHIBITOR_BUILDING',
#    'laneType': 'BOT_LANE',
#    'towerType': 'UNDEFINED_TURRET'},
#   {'type': 'BUILDING_KILL',
#    'timestamp': 2065579,
#    'position': {'x': 1748, 'y': 2270},
#    'killerId': 0,
#    'assistingParticipantIds': [],
#    'teamId': 100,
#    'buildingType': 'TOWER_BUILDING',
#    'laneType': 'MID_LANE',
#    'towerType': 'NEXUS_TURRET'},
#   {'type': 'WARD_PLACED',
#    'timestamp': 2068188,
#    'wardType': 'UNDEFINED',
#    'creatorId': 8},
#   {'type': 'ITEM_PURCHASED',
#    'timestamp': 2068519,
#    'participantId': 10,
#    'itemId': 3076},
#   {'type': 'ITEM_DESTROYED',
#    'timestamp': 2068519,
#    'participantId': 10,
#    'itemId': 1029},
#   {'type': 'ITEM_DESTROYED',
#    'timestamp': 2068519,
#    'participantId': 10,
#    'itemId': 1029},
#   {'type': 'BUILDING_KILL',
#    'timestamp': 2071162,
#    'position': {'x': 2177, 'y': 1807},
#    'killerId': 0,
#    'assistingParticipantIds': [7],
#    'teamId': 100,
#    'buildingType': 'TOWER_BUILDING',
#    'laneType': 'MID_LANE',
#    'towerType': 'NEXUS_TURRET'}],
#  'timestamp': 2100600}

# %%
tl['frames'][1]['timestamp']
# Out:
# 60021

# %%
tl['frames'][1]['events']
# Out:
# [{'type': 'ITEM_PURCHASED',
#   'timestamp': 4033,
#   'participantId': 1,
#   'itemId': 1055},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 4429,
#   'participantId': 1,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 4858,
#   'participantId': 1,
#   'itemId': 3340},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 5122,
#   'participantId': 10,
#   'itemId': 1039},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 5684,
#   'participantId': 10,
#   'itemId': 2031},
#  {'type': 'SKILL_LEVEL_UP',
#   'timestamp': 6377,
#   'participantId': 1,
#   'skillSlot': 1,
#   'levelUpType': 'NORMAL'},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 6410,
#   'participantId': 10,
#   'itemId': 3340},
#  {'type': 'SKILL_LEVEL_UP',
#   'timestamp': 7236,
#   'participantId': 6,
#   'skillSlot': 3,
#   'levelUpType': 'NORMAL'},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 7830,
#   'participantId': 8,
#   'itemId': 1055},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 8326,
#   'participantId': 8,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 9151,
#   'participantId': 8,
#   'itemId': 3340},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 10935,
#   'participantId': 6,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 11463,
#   'participantId': 6,
#   'itemId': 3858},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 11628,
#   'participantId': 5,
#   'itemId': 1056},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 12024,
#   'participantId': 5,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 12157,
#   'participantId': 4,
#   'itemId': 1055},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 12289,
#   'participantId': 5,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 12356,
#   'participantId': 6,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 12818,
#   'participantId': 6,
#   'itemId': 3340},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 12818,
#   'participantId': 5,
#   'itemId': 3340},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 13247,
#   'participantId': 4,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 13313,
#   'participantId': 2,
#   'itemId': 1041},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 13644,
#   'participantId': 4,
#   'itemId': 3340},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 13710,
#   'participantId': 2,
#   'itemId': 2031},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 14007,
#   'participantId': 2,
#   'itemId': 3340},
#  {'type': 'SKILL_LEVEL_UP',
#   'timestamp': 14106,
#   'participantId': 5,
#   'skillSlot': 1,
#   'levelUpType': 'NORMAL'},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 15823,
#   'participantId': 9,
#   'itemId': 1056},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 17111,
#   'participantId': 9,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 17276,
#   'participantId': 9,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 17838,
#   'participantId': 9,
#   'itemId': 3340},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 17838,
#   'participantId': 3,
#   'itemId': 3850},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 18003,
#   'participantId': 3,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 18300,
#   'participantId': 3,
#   'itemId': 3340},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 18696,
#   'participantId': 3,
#   'itemId': 2003},
#  {'type': 'SKILL_LEVEL_UP',
#   'timestamp': 22461,
#   'participantId': 3,
#   'skillSlot': 3,
#   'levelUpType': 'NORMAL'},
#  {'type': 'SKILL_LEVEL_UP',
#   'timestamp': 22692,
#   'participantId': 4,
#   'skillSlot': 1,
#   'levelUpType': 'NORMAL'},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 24509,
#   'participantId': 7,
#   'itemId': 1054},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 24839,
#   'participantId': 7,
#   'itemId': 2003},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 25136,
#   'participantId': 7,
#   'itemId': 3340},
#  {'type': 'WARD_PLACED',
#   'timestamp': 30751,
#   'wardType': 'YELLOW_TRINKET',
#   'creatorId': 1},
#  {'type': 'SKILL_LEVEL_UP',
#   'timestamp': 31676,
#   'participantId': 8,
#   'skillSlot': 1,
#   'levelUpType': 'NORMAL'},
#  {'type': 'WARD_PLACED',
#   'timestamp': 35771,
#   'wardType': 'YELLOW_TRINKET',
#   'creatorId': 10},
#  {'type': 'WARD_PLACED',
#   'timestamp': 43037,
#   'wardType': 'YELLOW_TRINKET',
#   'creatorId': 4},
#  {'type': 'WARD_PLACED',
#   'timestamp': 45581,
#   'wardType': 'YELLOW_TRINKET',
#   'creatorId': 6},
#  {'type': 'ITEM_PURCHASED',
#   'timestamp': 52617,
#   'participantId': 10,
#   'itemId': 3364},
#  {'type': 'ITEM_DESTROYED',
#   'timestamp': 52617,
#   'participantId': 10,
#   'itemId': 3340}]

# %%
events = pd.DataFrame(tl['frames'][4]['events'])

# %%
events
# Out:
#               type  timestamp  participantId  itemId        wardType  \
# 0   ITEM_DESTROYED     180199            5.0  2010.0             NaN
# 1      WARD_PLACED     182808            NaN     NaN  YELLOW_TRINKET
# 2    CHAMPION_KILL     186309            NaN     NaN             NaN
# 3    CHAMPION_KILL     194499            NaN     NaN             NaN
# 4   ITEM_DESTROYED     196051            8.0  2003.0             NaN
# 5   SKILL_LEVEL_UP     197603            6.0     NaN             NaN
# 6   SKILL_LEVEL_UP     198198            8.0     NaN             NaN
# 7   SKILL_LEVEL_UP     199354            5.0     NaN             NaN
# 8   ITEM_PURCHASED     200940            4.0  1001.0             NaN
# 9   ITEM_PURCHASED     201237            4.0  2003.0             NaN
# 10  ITEM_DESTROYED     202624            5.0  2003.0             NaN
# 11  SKILL_LEVEL_UP     204507            1.0     NaN             NaN
# 12  ITEM_PURCHASED     205695            7.0  1001.0             NaN
# 13  ITEM_DESTROYED     208701            9.0  2003.0             NaN
# 14  ITEM_DESTROYED     209031            5.0  2003.0             NaN
# 15  SKILL_LEVEL_UP     212201            3.0     NaN             NaN
# 16     WARD_PLACED     225147            NaN     NaN  YELLOW_TRINKET
# 17   CHAMPION_KILL     225279            NaN     NaN             NaN
# 18  ITEM_PURCHASED     235881            3.0  1004.0             NaN
# 19  ITEM_PURCHASED     235980            3.0  1004.0             NaN
# 20  ITEM_PURCHASED     236112            3.0  1004.0             NaN
# 21  ITEM_PURCHASED     238458            5.0  1052.0             NaN
#
#     creatorId                 position  killerId  victimId  \
# 0         NaN                      NaN       NaN       NaN
# 1         7.0                      NaN       NaN       NaN
# 2         NaN  {'x': 10709, 'y': 1213}       6.0       4.0
# 3         NaN  {'x': 3686, 'y': 13472}       1.0       7.0
# 4         NaN                      NaN       NaN       NaN
# 5         NaN                      NaN       NaN       NaN
# 6         NaN                      NaN       NaN       NaN
# 7         NaN                      NaN       NaN       NaN
# 8         NaN                      NaN       NaN       NaN
# 9         NaN                      NaN       NaN       NaN
# 10        NaN                      NaN       NaN       NaN
# 11        NaN                      NaN       NaN       NaN
# 12        NaN                      NaN       NaN       NaN
# 13        NaN                      NaN       NaN       NaN
# 14        NaN                      NaN       NaN       NaN
# 15        NaN                      NaN       NaN       NaN
# 16        2.0                      NaN       NaN       NaN
# 17        NaN  {'x': 10649, 'y': 1369}       8.0       3.0
# 18        NaN                      NaN       NaN       NaN
# 19        NaN                      NaN       NaN       NaN
# 20        NaN                      NaN       NaN       NaN
# 21        NaN                      NaN       NaN       NaN
#
#    assistingParticipantIds  skillSlot levelUpType
# 0                      NaN        NaN         NaN
# 1                      NaN        NaN         NaN
# 2                      [8]        NaN         NaN
# 3                      [2]        NaN         NaN
# 4                      NaN        NaN         NaN
# 5                      NaN        1.0      NORMAL
# 6                      NaN        1.0      NORMAL
# 7                      NaN        1.0      NORMAL
# 8                      NaN        NaN         NaN
# 9                      NaN        NaN         NaN
# 10                     NaN        NaN         NaN
# 11                     NaN        2.0      NORMAL
# 12                     NaN        NaN         NaN
# 13                     NaN        NaN         NaN
# 14                     NaN        NaN         NaN
# 15                     NaN        1.0      NORMAL
# 16                     NaN        NaN         NaN
# 17                     [6]        NaN         NaN
# 18                     NaN        NaN         NaN
# 19                     NaN        NaN         NaN
# 20                     NaN        NaN         NaN
# 21                     NaN        NaN         NaN

# %%
events['type'].unique()
# Out:
# array(['ITEM_DESTROYED', 'WARD_PLACED', 'CHAMPION_KILL', 'SKILL_LEVEL_UP',
#        'ITEM_PURCHASED'], dtype=object)

# %% [markdown]
# ## OOP version

# %%
class User(object):  
        
    
    def __init__(self, # self makes reference to the instance
                 name, 
                 api_key, 
                 summoner_name,    
                 ):
        
        self.name = name
        self.api_key = api_key
        self.summoner_name = summoner_name
        self.accountid = get_accountid(summoner, key)
     
    
    def new_apikey(self, key):
        self.api_key = key

# %%
events['position_x'] = [elem.get('x') if type(elem) == dict else 'none' for elem in events['position']]
events['position_y'] = [elem.get('y') if type(elem) == dict else 'none' for elem in events['position']]
events.drop(columns='position', inplace=True)

# %%
events.head()
# Out:
#              type  timestamp  participantId  itemId        wardType  \
# 0  ITEM_DESTROYED     180199            5.0  2010.0             NaN
# 1     WARD_PLACED     182808            NaN     NaN  YELLOW_TRINKET
# 2   CHAMPION_KILL     186309            NaN     NaN             NaN
# 3   CHAMPION_KILL     194499            NaN     NaN             NaN
# 4  ITEM_DESTROYED     196051            8.0  2003.0             NaN
#
#    creatorId  killerId  victimId assistingParticipantIds  skillSlot  \
# 0        NaN       NaN       NaN                     NaN        NaN
# 1        7.0       NaN       NaN                     NaN        NaN
# 2        NaN       6.0       4.0                     [8]        NaN
# 3        NaN       1.0       7.0                     [2]        NaN
# 4        NaN       NaN       NaN                     NaN        NaN
#
#   levelUpType position_x position_y
# 0         NaN       none       none
# 1         NaN       none       none
# 2         NaN      10709       1213
# 3         NaN       3686      13472
# 4         NaN       none       none

# %%
events['assistingParticipantIds'][2][0]
# Out:
# 8

# %%
events['assistingParticipantIds'] = [elem[0] if type(elem) == list else 'none' for elem in events['assistingParticipantIds']]

# %%
events
# Out:
#               type  timestamp  participantId  itemId        wardType  \
# 0   ITEM_DESTROYED     180199            5.0  2010.0             NaN
# 1      WARD_PLACED     182808            NaN     NaN  YELLOW_TRINKET
# 2    CHAMPION_KILL     186309            NaN     NaN             NaN
# 3    CHAMPION_KILL     194499            NaN     NaN             NaN
# 4   ITEM_DESTROYED     196051            8.0  2003.0             NaN
# 5   SKILL_LEVEL_UP     197603            6.0     NaN             NaN
# 6   SKILL_LEVEL_UP     198198            8.0     NaN             NaN
# 7   SKILL_LEVEL_UP     199354            5.0     NaN             NaN
# 8   ITEM_PURCHASED     200940            4.0  1001.0             NaN
# 9   ITEM_PURCHASED     201237            4.0  2003.0             NaN
# 10  ITEM_DESTROYED     202624            5.0  2003.0             NaN
# 11  SKILL_LEVEL_UP     204507            1.0     NaN             NaN
# 12  ITEM_PURCHASED     205695            7.0  1001.0             NaN
# 13  ITEM_DESTROYED     208701            9.0  2003.0             NaN
# 14  ITEM_DESTROYED     209031            5.0  2003.0             NaN
# 15  SKILL_LEVEL_UP     212201            3.0     NaN             NaN
# 16     WARD_PLACED     225147            NaN     NaN  YELLOW_TRINKET
# 17   CHAMPION_KILL     225279            NaN     NaN             NaN
# 18  ITEM_PURCHASED     235881            3.0  1004.0             NaN
# 19  ITEM_PURCHASED     235980            3.0  1004.0             NaN
# 20  ITEM_PURCHASED     236112            3.0  1004.0             NaN
# 21  ITEM_PURCHASED     238458            5.0  1052.0             NaN
#
#     creatorId  killerId  victimId assistingParticipantIds  skillSlot  \
# 0         NaN       NaN       NaN                    none        NaN
# 1         7.0       NaN       NaN                    none        NaN
# 2         NaN       6.0       4.0                       8        NaN
# 3         NaN       1.0       7.0                       2        NaN
# 4         NaN       NaN       NaN                    none        NaN
# 5         NaN       NaN       NaN                    none        1.0
# 6         NaN       NaN       NaN                    none        1.0
# 7         NaN       NaN       NaN                    none        1.0
# 8         NaN       NaN       NaN                    none        NaN
# 9         NaN       NaN       NaN                    none        NaN
# 10        NaN       NaN       NaN                    none        NaN
# 11        NaN       NaN       NaN                    none        2.0
# 12        NaN       NaN       NaN                    none        NaN
# 13        NaN       NaN       NaN                    none        NaN
# 14        NaN       NaN       NaN                    none        NaN
# 15        NaN       NaN       NaN                    none        1.0
# 16        2.0       NaN       NaN                    none        NaN
# 17        NaN       8.0       3.0                       6        NaN
# 18        NaN       NaN       NaN                    none        NaN
# 19        NaN       NaN       NaN                    none        NaN
# 20        NaN       NaN       NaN                    none        NaN
# 21        NaN       NaN       NaN                    none        NaN
#
#    levelUpType position_x position_y
# 0          NaN       none       none
# 1          NaN       none       none
# 2          NaN      10709       1213
# 3          NaN       3686      13472
# 4          NaN       none       none
# 5       NORMAL       none       none
# 6       NORMAL       none       none
# 7       NORMAL       none       none
# 8          NaN       none       none
# 9          NaN       none       none
# 10         NaN       none       none
# 11      NORMAL       none       none
# 12         NaN       none       none
# 13         NaN       none       none
# 14         NaN       none       none
# 15      NORMAL       none       none
# 16         NaN       none       none
# 17         NaN      10649       1369
# 18         NaN       none       none
# 19         NaN       none       none
# 20         NaN       none       none
# 21         NaN       none       none

# %%
events.dtypes
# Out:
# type                        object
# timestamp                    int64
# participantId              float64
# itemId                     float64
# wardType                    object
# creatorId                  float64
# killerId                   float64
# victimId                   float64
# assistingParticipantIds     object
# skillSlot                  float64
# levelUpType                 object
# position_x                  object
# position_y                  object
# dtype: object

# %%
num_feat = events.select_dtypes(include=np.number).columns.to_list()
cat_feat = events.select_dtypes(include='object').columns.to_list()
num_df = events[num_feat]
cat_df = events[cat_feat].astype('category')

# %%
events = pd.concat([cat_df, num_df], axis=1)
events.dtypes
# Out:
# type                       category
# wardType                   category
# assistingParticipantIds    category
# levelUpType                category
# position_x                 category
# position_y                 category
# timestamp                     int64
# participantId               float64
# itemId                      float64
# creatorId                   float64
# killerId                    float64
# victimId                    float64
# skillSlot                   float64
# dtype: object

# %%
event = events[['type', 'wardType','assistingParticipantIds']]
event
# Out:
#               type        wardType assistingParticipantIds
# 0   ITEM_DESTROYED             NaN                    none
# 1      WARD_PLACED  YELLOW_TRINKET                    none
# 2    CHAMPION_KILL             NaN                       8
# 3    CHAMPION_KILL             NaN                       2
# 4   ITEM_DESTROYED             NaN                    none
# 5   SKILL_LEVEL_UP             NaN                    none
# 6   SKILL_LEVEL_UP             NaN                    none
# 7   SKILL_LEVEL_UP             NaN                    none
# 8   ITEM_PURCHASED             NaN                    none
# 9   ITEM_PURCHASED             NaN                    none
# 10  ITEM_DESTROYED             NaN                    none
# 11  SKILL_LEVEL_UP             NaN                    none
# 12  ITEM_PURCHASED             NaN                    none
# 13  ITEM_DESTROYED             NaN                    none
# 14  ITEM_DESTROYED             NaN                    none
# 15  SKILL_LEVEL_UP             NaN                    none
# 16     WARD_PLACED  YELLOW_TRINKET                    none
# 17   CHAMPION_KILL             NaN                       6
# 18  ITEM_PURCHASED             NaN                    none
# 19  ITEM_PURCHASED             NaN                    none
# 20  ITEM_PURCHASED             NaN                    none
# 21  ITEM_PURCHASED             NaN                    none

# %%
event.to_sql('events', con=engine, if_exists='append', index_label='id')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-3507eaead6b6> in <module>
# ----> 1 event.to_sql('events', con=engine, if_exists='append', index_label='id')
#
# NameError: name 'engine' is not defined

# %%
from DB import engine
